# %% [markdown]
# <a href="https://colab.research.google.com/github/JonatasFontele/aprendizagem-de-maquina-e-mineracao-de-dados/blob/main/ootimista_quantidade_coment%C3%A1rios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Análise estatística de quantidade de comentários por usuário e por membro do CDS na postagem de curtidas da Startup MeMemoria do perfil de instagram @ootimista

# %%
import pandas as pd
pd.set_option("display.max_rows", None)

# %% [markdown]
# ##Amostra dos dados

# %%
df = pd.read_csv("ootimista_mememoria_post.csv", sep=';')

df.head()
# Out:
#              type                 id     username  \
# 0         comment  17955474074232200  jonyfontele
# 1         comment  17929506602561800  jonyfontele
# 2  comment-answer  17907867977665400  m4no_mateus
# 3         comment  17995152289594100  jonyfontele
# 4  comment-answer  17976392821853600  m4no_mateus
#
#                           text              date
# 0              Inovador!!! 👏👏👏  26/11/2022 00:30
# 1       De muito interesse 👏👏👏  26/11/2022 03:15
# 2         @jonyfontele verdade  26/11/2022 04:24
# 3                   Wonderful!  26/11/2022 04:15
# 4  @jonyfontele também acho!!!  26/11/2022 04:25

# %% [markdown]
# ##10000 comentários que foram possíveis de baixar do instagram

# %%
df.shape # (linhas, colunas)
# Out:
# (10000, 5)

# %% [markdown]
# ##Quantidade de comentários por membros do CDS

# %%
jonatas = df['username'] == 'jonyfontele'
janaina = df['username'] == 'janaina_lima_santos'
mateus = df['username'] == 'm4no_mateus'
romulo = df['username'] == 'romulo.0.9'
cds = [df[jonatas], df[janaina], df[mateus], df[romulo]]
cds_comments = pd.concat(cds)
cds_comments['username'].value_counts()
# Out:
# jonyfontele            491
# janaina_lima_santos    320
# m4no_mateus            133
# romulo.0.9              57
# Name: username, dtype: int64

# %% [markdown]
# ##Quantidade de comentários por usuário

# %%
df['username'].value_counts()
# Out:
# jonyfontele                       491
# _sarahcunhamedeiros               424
# hirosh_xx                         423
# oliveira__isana                   414
# colecionamos__pessoas_memorias    401
# linemarialopes                    377
# janaina_lima_santos               320
# felipe.rezende.15                 308
# biellima.09                       285
# carolina_llima_                   243
# matheussilva_21                   231
# lirdaniia_                        211
# gurgelfabio                       194
# abeatrzcosta                      184
# _luizaudo                         176
# crixzin                           149
# goguibt                           145
# gabrielgemenes__                  141
# pscyo_sem_amigos                  139
# lucassousaalvess                  134
# m4no_mateus                       133
# rafaelloviana                     127
# emanuel_fortes_                   124
# nelson_almei                      123
# sheillacostta_                    119
# ...
